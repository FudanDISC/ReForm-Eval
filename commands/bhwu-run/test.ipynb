# %%
# check list
check_list=[
    "MSCOCO/image-text-matching-object-sampled.json",
    "MSCOCO/image-text-selection-object-sampled.json",
    "WikiHow/wikihow-image-text-selection-in-method-sampled.json",
    "SNLI_VE/visual-entailment-matching-sampled.json",
    "MEDIC/disaster-type-selection-sampled.json",
    "RefCOCO/referring-expression-selection-sampled.json",
    "MSCOCO/captions-sampled.json",
    "TextCaps/captions-sampled.json",
    "NoCaps/captions-sampled.json",
    "Flickr30K/captions-sampled.json",
]
check_obj=check_list[0]
from datasets import load_dataset #从multimodal-datasets中的hugging_face找到hf_json

# %%
test = load_dataset("json", data_files={'test':"/remote-home/share/multimodal-datasets/huggingface_data/Flickr30K/captions-sampled.json"}, split='test')
# print(test[0]['data'][0]) #test和['data']之间的[0]不可以省略
for k,v in test[0]['data'][0].items():
    print(f"{k}:{v}")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# img:...
# annos:['Men standing around a car with a lamp behind them .', 'A movie with a car is being filmed on the street .', 'A car being prepared for a photo shoot .', 'Four men standing near a yellow car .', 'Interior of yellow car is filmed .']
